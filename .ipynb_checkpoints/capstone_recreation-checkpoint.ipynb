# %% [markdown]
# ## Capstone - Predicting the Regions of Campgrounds in the US. from https://ridb.recreation.gov/

# %% [markdown]
# Data Aquisition: I got the data from the recreation.gov website. In addition to downloading the data, I reviewed the data dictionary and looked at the Entity Relationship diagram. In my investigation, it turned out that there is a Camping dataset that maps to the Reservations dataset. I mapped the data from thie dataset and excluded the others as described later in this notebook.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import datetime
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, r2_score
from sklearn.cluster import DBSCAN

import scipy.stats as stats
from sklearn.tree import DecisionTreeRegressor

from ipywidgets import *
from IPython.display import display


plt.rc("figure", figsize=(9, 7))
sns.set_style('whitegrid')

from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# %%
df15 = pd.read_csv('/Users/stevenmandel/Downloads/2015.csv',encoding='ISO-8859-1',error_bad_lines=False)

# %%
df15.columns
# Out:
# Index(['HistoricalReservationID', 'OrderNumber', 'Agency', 'OrgID',
#        'CodeHierarchy', 'RegionCode', 'RegionDescription', 'ParentLocationID',
#        'ParentLocation', 'LegacyFacilityID', 'Park', 'SiteType', 'UseType',
#        'ProductID', 'EntityType', 'EntityID', 'FacilityID', 'FacilityZIP',
#        'FacilityState', 'FacilityLongitude', 'FacilityLatitude', 'CustomerZIP',
#        'CustomerState', 'CustomerCountry', 'Tax', 'UseFee', 'TranFee',
#        'AttrFee', 'TotalBeforeTax', 'TotalPaid', 'StartDate', 'EndDate',
#        'OrderDate', 'NumberOfPeople', 'Tent', 'Popup', 'Trailer',
#        'RVMotorhome', 'Boat', 'HorseTrailer', 'Car', 'FifthWheel', 'Van',
#        'CanoeKayak', 'BoatTrailer', 'Motorcycle', 'Truck', 'Bus', 'Bicycle',
#        'Snowmobile', 'OffRoadlAllTerrainVehicle', 'PowerBoat', 'PickupCamper',
#        'LargeTentOver9x12', 'SmallTent', 'Marinaboat'],
#       dtype='object')

# %%
df15['FacilityID'].head()
# Out:
# 0    234164.0
# 1    233619.0
# 2    234735.0
# 3    232748.0
# 4    234735.0
# Name: FacilityID, dtype: float64

# %%
df15['EntityType'].head(10) # Looking at the data dictionary, it turns out that the only camping related entity type is "Site"
# Out:
# 0        Site
# 1        Site
# 2    Entrance
# 3         POS
# 4    Entrance
# 5         POS
# 6     LOTTERY
# 7        Site
# 8        Site
# 9        Site
# Name: EntityType, dtype: object

# %% [markdown]
# # Download Camping specific dataset

# %% [markdown]
# The camping specific dataset contains FacilityID which are specific to parks that have camping specific facilities. In order to only have camping-related reservationships, it was necessary to identify the unique FacilityIDs and then run a lambda function to map the Facility ID of the reservation dataset only to those in the Campsite dataset that match up with the unique FacilityID and assign it back to a new dataframe (df15Camp1a). It was necessary to rename the FacilityID to match the same case as in the Campground dataset.

# %%
df15.columns
# Out:
# Index(['HistoricalReservationID', 'OrderNumber', 'Agency', 'OrgID',
#        'CodeHierarchy', 'RegionCode', 'RegionDescription', 'ParentLocationID',
#        'ParentLocation', 'LegacyFacilityID', 'Park', 'SiteType', 'UseType',
#        'ProductID', 'EntityType', 'EntityID', 'FacilityID', 'FacilityZIP',
#        'FacilityState', 'FacilityLongitude', 'FacilityLatitude', 'CustomerZIP',
#        'CustomerState', 'CustomerCountry', 'Tax', 'UseFee', 'TranFee',
#        'AttrFee', 'TotalBeforeTax', 'TotalPaid', 'StartDate', 'EndDate',
#        'OrderDate', 'NumberOfPeople', 'Tent', 'Popup', 'Trailer',
#        'RVMotorhome', 'Boat', 'HorseTrailer', 'Car', 'FifthWheel', 'Van',
#        'CanoeKayak', 'BoatTrailer', 'Motorcycle', 'Truck', 'Bus', 'Bicycle',
#        'Snowmobile', 'OffRoadlAllTerrainVehicle', 'PowerBoat', 'PickupCamper',
#        'LargeTentOver9x12', 'SmallTent', 'Marinaboat'],
#       dtype='object')

# %%
dftemp = pd.read_csv('/Users/stevenmandel/Downloads/RIDBFullExport_v1/Campsites_API_v1.csv',encoding='ISO-8859-1',error_bad_lines=False)

# %%
dftemp = dftemp.rename(columns={'FACILITYID':'FacilityID'})

# %%
dftemp.FacilityID.dtypes
# Out:
# dtype('int64')

# %%
dftemp.shape
# Out:
# (99018, 9)

# %%
df15.FacilityID.dtypes
# Out:
# dtype('float64')

# %%
df15['FacilityID'].shape # before mapping, df15['FacilityID'].shape is 2949219,
# Out:
# (2949219,)

# %%
dftemp['FacilityID'].shape # before mapping, dftemp['FacilityID'].shape is 99018,
# Out:
# (99018,)

# %%
df15['FacilityID'].head()
# Out:
# 0    234164.0
# 1    233619.0
# 2    234735.0
# 3    232748.0
# 4    234735.0
# Name: FacilityID, dtype: float64

# %%
len(df15['FacilityID'].unique()) # len(df15['FacilityID'].unique()) b4 mapping is 3089
# Out:
# 3089

# %%
uniq = dftemp['FacilityID'].unique()

# %%
uniq
# Out:
# array([232446, 232448, 232447, ..., 272094, 272098, 272097])

# %%
df15Camp1a = df15[df15['FacilityID'].map(lambda x: True if x in uniq else False)]

# %% [markdown]
# # Data Cleaning

# %%
df15Camp1a.shape
# Out:
# (2186714, 56)

# %%
df15Camp1a.columns
# Out:
# Index(['HistoricalReservationID', 'OrderNumber', 'Agency', 'OrgID',
#        'CodeHierarchy', 'RegionCode', 'RegionDescription', 'ParentLocationID',
#        'ParentLocation', 'LegacyFacilityID', 'Park', 'SiteType', 'UseType',
#        'ProductID', 'EntityType', 'EntityID', 'FacilityID', 'FacilityZIP',
#        'FacilityState', 'FacilityLongitude', 'FacilityLatitude', 'CustomerZIP',
#        'CustomerState', 'CustomerCountry', 'Tax', 'UseFee', 'TranFee',
#        'AttrFee', 'TotalBeforeTax', 'TotalPaid', 'StartDate', 'EndDate',
#        'OrderDate', 'NumberOfPeople', 'Tent', 'Popup', 'Trailer',
#        'RVMotorhome', 'Boat', 'HorseTrailer', 'Car', 'FifthWheel', 'Van',
#        'CanoeKayak', 'BoatTrailer', 'Motorcycle', 'Truck', 'Bus', 'Bicycle',
#        'Snowmobile', 'OffRoadlAllTerrainVehicle', 'PowerBoat', 'PickupCamper',
#        'LargeTentOver9x12', 'SmallTent', 'Marinaboat'],
#       dtype='object')

# %%
df15Camp1a[df15Camp1a['FacilityID'].isin([232448])].sort_values(['HistoricalReservationID']).head() # just checking
# Out:
#         HistoricalReservationID OrderNumber Agency  OrgID  \
# 583672               1832830060  2-30960305    NPS    128
# 583699               1832876908  2-30960014    NPS    128
# 583743               1832921983  2-30961839    NPS    128
# 712969               1832953200  2-30962917    NPS    128
# 583780               1832975491  2-30962331    NPS    128
#
#                       CodeHierarchy RegionCode       RegionDescription  \
# 583672  |1|70904|74327|74296|70926|  YOSE-8800  Yosemite National Park
# 583699  |1|70904|74327|74296|70926|  YOSE-8800  Yosemite National Park
# 583743  |1|70904|74327|74296|70926|  YOSE-8800  Yosemite National Park
# 712969  |1|70904|74327|74296|70926|  YOSE-8800  Yosemite National Park
# 583780  |1|70904|74327|74296|70926|  YOSE-8800  Yosemite National Park
#
#         ParentLocationID       ParentLocation  LegacyFacilityID     ...      \
# 583672             74327  Pacific West Region             70926     ...
# 583699             74327  Pacific West Region             70926     ...
# 583743             74327  Pacific West Region             70926     ...
# 712969             74327  Pacific West Region             70926     ...
# 583780             74327  Pacific West Region             70926     ...
#
#        Truck Bus Bicycle  Snowmobile OffRoadlAllTerrainVehicle  PowerBoat  \
# 583672   NaN NaN     NaN         NaN                       NaN        NaN
# 583699   NaN NaN     NaN         NaN                       NaN        NaN
# 583743   NaN NaN     NaN         NaN                       NaN        NaN
# 712969   NaN NaN     NaN         NaN                       NaN        NaN
# 583780   NaN NaN     NaN         NaN                       NaN        NaN
#
#         PickupCamper LargeTentOver9x12 SmallTent  Marinaboat
# 583672           NaN               1.0       NaN         NaN
# 583699           NaN               NaN       NaN         NaN
# 583743           NaN               NaN       NaN         NaN
# 712969           NaN               NaN       NaN         NaN
# 583780           NaN               NaN       NaN         NaN
#
# [5 rows x 56 columns]

# %%
df15Camp1a.EntityType.value_counts()
# Out:
# Site    1965887
# POS      220827
# Name: EntityType, dtype: int64

# %%
df15Camp1a.columns
# Out:
# Index(['HistoricalReservationID', 'OrderNumber', 'Agency', 'OrgID',
#        'CodeHierarchy', 'RegionCode', 'RegionDescription', 'ParentLocationID',
#        'ParentLocation', 'LegacyFacilityID', 'Park', 'SiteType', 'UseType',
#        'ProductID', 'EntityType', 'EntityID', 'FacilityID', 'FacilityZIP',
#        'FacilityState', 'FacilityLongitude', 'FacilityLatitude', 'CustomerZIP',
#        'CustomerState', 'CustomerCountry', 'Tax', 'UseFee', 'TranFee',
#        'AttrFee', 'TotalBeforeTax', 'TotalPaid', 'StartDate', 'EndDate',
#        'OrderDate', 'NumberOfPeople', 'Tent', 'Popup', 'Trailer',
#        'RVMotorhome', 'Boat', 'HorseTrailer', 'Car', 'FifthWheel', 'Van',
#        'CanoeKayak', 'BoatTrailer', 'Motorcycle', 'Truck', 'Bus', 'Bicycle',
#        'Snowmobile', 'OffRoadlAllTerrainVehicle', 'PowerBoat', 'PickupCamper',
#        'LargeTentOver9x12', 'SmallTent', 'Marinaboat'],
#       dtype='object')

# %%
df15Camp1a.iloc[:5,11:19]
# Out:
#              SiteType    UseType  ProductID EntityType  EntityID  FacilityID  \
# 0             WALK TO  Overnight     145251       Site   15124.0    234164.0
# 1   STANDARD ELECTRIC  Overnight     120875       Site   50064.0    233619.0
# 3  DAYU-CASH REGISTER       None     262899        POS       NaN    232748.0
# 5    DUMP STATION FEE       None     262851        POS       NaN    232626.0
# 7   STANDARD ELECTRIC  Overnight      77173       Site   28057.0    232702.0
#
#   FacilityZIP FacilityState
# 0         NaN            ID
# 1         NaN            OK
# 3         NaN            TX
# 5         NaN            TX
# 7       37214            TN

# %% [markdown]
# Drop the following columns that either have no data or are not relevant.

# %%
df15Camp1a.isnull().sum().sort_values()
# Out:
# HistoricalReservationID            0
# NumberOfPeople                     0
# OrderDate                          0
# TotalPaid                          0
# TotalBeforeTax                     0
# TranFee                            0
# UseFee                             0
# Tax                                0
# FacilityState                      0
# FacilityID                         0
# EntityType                         0
# ProductID                          0
# AttrFee                            0
# SiteType                           0
# OrgID                              0
# CodeHierarchy                      0
# UseType                            0
# RegionCode                         0
# RegionDescription                  0
# ParentLocationID                   0
# Agency                             0
# OrderNumber                        0
# ParentLocation                     0
# LegacyFacilityID                   0
# Park                               0
# CustomerCountry                    2
# FacilityLatitude                  54
# FacilityLongitude                 54
# CustomerZIP                     4922
# CustomerState                   7861
# StartDate                     223003
# EndDate                       223003
# EntityID                      268215
# FacilityZIP                  1280900
# Tent                         1543805
# Trailer                      1875658
# RVMotorhome                  1979976
# FifthWheel                   2051205
# Popup                        2116916
# Van                          2150165
# PickupCamper                 2159925
# LargeTentOver9x12            2172120
# SmallTent                    2173874
# Boat                         2186264
# PowerBoat                    2186714
# OffRoadlAllTerrainVehicle    2186714
# Snowmobile                   2186714
# Bicycle                      2186714
# Motorcycle                   2186714
# Truck                        2186714
# BoatTrailer                  2186714
# CanoeKayak                   2186714
# Car                          2186714
# HorseTrailer                 2186714
# Bus                          2186714
# Marinaboat                   2186714
# dtype: int64

# %%
df15Camp1a = df15Camp1a.drop(labels=['HistoricalReservationID','LegacyFacilityID','ParentLocationID','OrgID','FacilityID','EntityID','FacilityZIP'], axis=1).copy()

# %%
df15Camp1a = df15Camp1a.drop(labels=['ProductID','PowerBoat','OffRoadlAllTerrainVehicle','Snowmobile','Bicycle','Motorcycle','Truck','BoatTrailer','CanoeKayak','Car','HorseTrailer','Bus','Marinaboat','Boat'], axis=1).copy()

# %%
df15Camp1a.shape
# Out:
# (2186714, 35)

# %% [markdown]
# # Drop NA Values

# %% [markdown]
# These items below are specific to the type of camping being done. In some cases there may be a small tent and a large tent, for instance, but for the most part they are unique means of camping. There were some cases in which nothing was specified as it is an optional field but most of them contained a value. As such, I did a dropna and set 'how' to 'all'. This way only those that contained no value at all would be dropped. Later, the remaining null values will be imputed to 0 as they already contain a specified value.

# %%
df15Camp1a.dropna(subset=['Tent','Popup','Trailer', 'RVMotorhome', 'FifthWheel', 'Van','PickupCamper','SmallTent'],how='all', inplace=True)

# %%
df15Camp1a.columns
# Out:
# Index(['OrderNumber', 'Agency', 'CodeHierarchy', 'RegionCode',
#        'RegionDescription', 'ParentLocation', 'Park', 'SiteType', 'UseType',
#        'EntityType', 'FacilityState', 'FacilityLongitude', 'FacilityLatitude',
#        'CustomerZIP', 'CustomerState', 'CustomerCountry', 'Tax', 'UseFee',
#        'TranFee', 'AttrFee', 'TotalBeforeTax', 'TotalPaid', 'StartDate',
#        'EndDate', 'OrderDate', 'NumberOfPeople', 'Tent', 'Popup', 'Trailer',
#        'RVMotorhome', 'FifthWheel', 'Van', 'PickupCamper', 'LargeTentOver9x12',
#        'SmallTent'],
#       dtype='object')

# %%
df15Camp1a.CustomerZIP.dropna(how='any',inplace=True)

# %%
df15Camp1a.CustomerState.dropna(how='any',inplace=True)

# %%
df15Camp1a.dropna(subset=['FacilityLongitude','FacilityLatitude', 'CustomerZIP','CustomerState','CustomerCountry'],how='any',inplace=True)

# %%
df15Camp1a.isnull().sum().sort_values()
# Out:
# OrderNumber                0
# NumberOfPeople             0
# OrderDate                  0
# EndDate                    0
# StartDate                  0
# TotalPaid                  0
# TotalBeforeTax             0
# AttrFee                    0
# TranFee                    0
# Tax                        0
# CustomerCountry            0
# CustomerState              0
# CustomerZIP                0
# UseFee                     0
# FacilityLongitude          0
# Agency                     0
# FacilityLatitude           0
# RegionCode                 0
# RegionDescription          0
# ParentLocation             0
# CodeHierarchy              0
# SiteType                   0
# UseType                    0
# EntityType                 0
# FacilityState              0
# Park                       0
# Tent                  784353
# Trailer              1111125
# RVMotorhome          1219537
# FifthWheel           1286706
# Popup                1352358
# Van                  1387116
# PickupCamper         1395383
# SmallTent            1409492
# LargeTentOver9x12    1421994
# dtype: int64

# %% [markdown]
# # Set Dates to Date Time format

# %% [markdown]
# Convert dates to be in datetime format so that they can be used in calculations. Ultimately we will be looking at the median Order Month and median Start Month for each park and using thees as features in the model.

# %%
df15Camp1a['OrderDate'] = pd.to_datetime(df15Camp1a['OrderDate'])

df15Camp1a['OrderYear'] = df15Camp1a['OrderDate'].dt.year

df15Camp1a['OrderMonth'] = df15Camp1a['OrderDate'].dt.month

df15Camp1a['OrderDay']  = df15Camp1a['OrderDate'].dt.day

# %%
df15Camp1a['StartDate'] = pd.to_datetime(df15Camp1a['StartDate'])

df15Camp1a['StartMonth'] = df15Camp1a['StartDate'].dt.month

df15Camp1a['StartDay'] = df15Camp1a['StartDate'].dt.day

df15Camp1a['StartYear'] = df15Camp1a['StartDate'].dt.year
df15Camp1a['StartDate'].head()
# Out:
# 0    2015-08-21
# 7    2015-09-23
# 8    2015-10-10
# 12   2015-09-25
# 13   2015-09-25
# Name: StartDate, dtype: datetime64[ns]

# %%
df15Camp1a['EndDate'] = pd.to_datetime(df15Camp1a['EndDate'])

df15Camp1a['EndMonth'] = df15Camp1a['EndDate'].dt.month

df15Camp1a['EndDay'] = df15Camp1a['EndDate'].dt.day

df15Camp1a['EndYear'] = df15Camp1a['EndDate'].dt.year



df15Camp1a['EndDate'].head()
# Out:
# 0    2015-08-23
# 7    2015-09-25
# 8    2015-10-12
# 12   2015-09-27
# 13   2015-09-26
# Name: EndDate, dtype: datetime64[ns]

# %% [markdown]
# Create a csv file of the cleaned data.

# %%
df15Camp1a.to_csv('df15Camp1a.csv', index=False)

# %% [markdown]
# # Get the median dates for Order Month and Start Month

# %% [markdown]
# While I chose the 2015 Reservation dataset, there were cases that crossed over the year. To handle this, I set the OrderYear and StartYear to be 2015. Then I calculated the mean order month and mean start month for the parks and renamed the columns to reflect this.

# %%
Twenty_Fifteen_dates = df15Camp1a.loc[(df15Camp1a['OrderYear'] == 2015) & (df15Camp1a['StartYear'] == 2015), :] # use

Order_Start_Month2015 = Twenty_Fifteen_dates.groupby('Park')[['OrderMonth', 'StartMonth']].median() # use

Order_Start_Month2015.rename(columns={'OrderMonth':'MedianOrderMo', 'StartMonth':'MedianStartMo'}, inplace=True) # use

Order_Start_Month2015.head()
# Out:
#                      MedianOrderMo  MedianStartMo
# Park
# ACKERMAN CAMPGROUND            6.0            7.0
# ACORN CAMPGROUND               2.0            2.0
# ACORN VALLEY                   6.0            7.0
# ADELAIDE CAMPGROUND            5.0            7.0
# AIRPORT PARK                   3.0            5.0

# %% [markdown]
# # Use Groupby to group by Individual Parks

# %% [markdown]
# Due to the fact that the data we are working with is transactional -- reservations that were booked to campsites, it is necessary to group the data. For example, a single reservation at a park will contain all of the pertinent data such as the order date, the total, whether it will be for tent camping or an RV, etc. By grouping all of the reservations per park, we are able to obtain the sums of all the relevant data.

# %%
df15Camp1a = df15Camp1a.groupby('Park')[['SiteType', 'UseType',
       'EntityType', 'FacilityState', 
       'CustomerZIP', 'CustomerState', 'CustomerCountry', 'Tax', 'UseFee',
       'TranFee', 'AttrFee', 'TotalBeforeTax', 'TotalPaid', 'StartDate',
       'EndDate', 'OrderDate', 'NumberOfPeople', 'Tent', 'Popup', 'Trailer',
       'RVMotorhome', 'FifthWheel', 'Van', 'PickupCamper', 'SmallTent']].sum()

# %%
df15Camp1a = df15Camp1a.reset_index().copy()

# %%
df15Camp1a.head()
# Out:
#                   Park  Tax   UseFee  TranFee  AttrFee  TotalBeforeTax  \
# 0  ACKERMAN CAMPGROUND  0.0   2398.5   1513.0      0.0          3920.5
# 1     ACORN CAMPGROUND  0.0  17596.0    950.0      0.0         18584.0
# 2         ACORN VALLEY  0.0   5649.0    662.0      0.0          6621.0
# 3  ADELAIDE CAMPGROUND  0.0   1500.0    176.0      0.0          1726.0
# 4         AIRPORT PARK  0.0  55616.0   2660.0      0.0         59118.0
#
#    TotalPaid  NumberOfPeople   Tent  Popup  Trailer  RVMotorhome  FifthWheel  \
# 0     3920.5             520   88.0    5.0     23.0          7.0         4.0
# 1    18584.0            2913  441.0   18.0    121.0        117.0        69.0
# 2     6621.0            1202  281.0    NaN      NaN          NaN         NaN
# 3     1726.0             466   19.0    1.0      3.0          3.0         NaN
# 4    59118.0            9603  162.0   39.0    882.0        631.0       471.0
#
#     Van  PickupCamper  SmallTent
# 0   3.0           5.0        NaN
# 1  89.0          32.0        NaN
# 2   NaN           NaN        2.0
# 3   NaN           NaN        NaN
# 4  16.0          16.0        NaN

# %%
df15Camp1a.columns
# Out:
# Index(['Park', 'Tax', 'UseFee', 'TranFee', 'AttrFee', 'TotalBeforeTax',
#        'TotalPaid', 'NumberOfPeople', 'Tent', 'Popup', 'Trailer',
#        'RVMotorhome', 'FifthWheel', 'Van', 'PickupCamper', 'SmallTent'],
#       dtype='object')

# %% [markdown]
# # Create ParkState to keep track of Parks within States

# %% [markdown]
# FacilityState was removed after the groupby. By creating a dictionary from the original Reservations dataset and mapping FacilityState to Park.

# %%
ParkState = df15[['Park','FacilityState']] 

my_dict = ParkState.set_index('Park').to_dict()
contents = my_dict['FacilityState'] #.keys()

# %%
df15Camp1a['FacilityState'] = df15Camp1a['Park'].map(contents)

# %%
df15Camp1a['FacilityState'].head()
# Out:
# 0    CA
# 1    CA
# 2    IA
# 3    UT
# 4    TX
# Name: FacilityState, dtype: object

# %% [markdown]
# # Create Regions and Map States to Regions

# %% [markdown]
# In looking at the data, there were some distinct differences across regions as far as things such as the type of the equipment used for camping, as well as the average start months. As a result, I created 10 regions and mapped each state to a region. The regions will be the target in my models.

# %%
def toRegion(FacilityState):
    if FacilityState in ['WA', 'OR', 'CA']:
        return 'Pacific Coast'
    elif FacilityState in ['VA', 'WV','NC', 'TN', 'KY']:
        return 'Appalachian'
    elif FacilityState in ['NY', 'NJ', 'PA', 'DE','MD']:
        return 'Mid Atlantic'
    elif FacilityState in ['ME', 'VT', 'NH', 'MA', 'CT', 'RI' ]:
        return 'New England'
    elif FacilityState in ['AR','LA', 'MS', 'AL', 'GA', 'FL', 'SC']:
        return 'Southeast'
    elif FacilityState in ['OH', 'MI', 'WI', 'IL', 'IN']:
        return 'Midwest' 
    elif FacilityState in ['MN', 'ND', 'SD', 'IA', 'NE', 'MO', 'KS']:
        return 'Heartland' 
    elif FacilityState in ['AZ', 'NM', 'TX', 'OK']:
        return 'Southwest'
    elif FacilityState in ['ID', 'MT', 'CO', 'WY', 'UT', 'NV']:
        return 'Mountain'
    elif FacilityState in ['AK', 'HI']:
        return 'Noncontiguous'

# %%
df15Camp1a['Region'] = df15Camp1a['FacilityState'].map(toRegion)

# %%
df15Camp1a.columns
# Out:
# Index(['Park', 'Tax', 'UseFee', 'TranFee', 'AttrFee', 'TotalBeforeTax',
#        'TotalPaid', 'NumberOfPeople', 'Tent', 'Popup', 'Trailer',
#        'RVMotorhome', 'FifthWheel', 'Van', 'PickupCamper', 'SmallTent',
#        'FacilityState', 'Region'],
#       dtype='object')

# %% [markdown]
# # Merge the Median Order and Median Start Month (from above) to the dataframe

# %%
df15CampFinal= pd.merge(Order_Start_Month2015.reset_index(), df15Camp1a, on='Park')

# %%
df15CampFinal.to_csv('df15CampFinal.csv', index=False)

# %% [markdown]
# # Impute null values to be 0

# %% [markdown]
# Most of the null values resulted from categorical items such as Tent, RV, Van, Fifth Wheel, etc. Most reservations consisted of one or two of these. Note that these attributes are optional. I chose to impute the remaining null values to zero.

# %%
df15CampFinal.isnull().sum()
# Out:
# Park                 0
# MedianOrderMo        0
# MedianStartMo        0
# Tax                  0
# UseFee               0
# TranFee              0
# AttrFee              0
# TotalBeforeTax       0
# TotalPaid            0
# NumberOfPeople       0
# Tent                44
# Popup              489
# Trailer            325
# RVMotorhome        341
# FifthWheel         523
# Van                619
# PickupCamper       573
# SmallTent         1936
# FacilityState        0
# Region               0
# dtype: int64

# %%
df15CampFinal[['Tent','Trailer','RVMotorhome','FifthWheel','Popup','Van','PickupCamper', 'SmallTent']] = df15CampFinal[['Tent','Trailer','RVMotorhome','FifthWheel','Popup','Van','PickupCamper', 'SmallTent']].fillna(value=0)

# %%
df15CampFinal.isnull().sum()
# Out:
# Park              0
# MedianOrderMo     0
# MedianStartMo     0
# Tax               0
# UseFee            0
# TranFee           0
# AttrFee           0
# TotalBeforeTax    0
# TotalPaid         0
# NumberOfPeople    0
# Tent              0
# Popup             0
# Trailer           0
# RVMotorhome       0
# FifthWheel        0
# Van               0
# PickupCamper      0
# SmallTent         0
# FacilityState     0
# Region            0
# dtype: int64

# %% [markdown]
# # EDA

# %%
df15CampFinal.shape
# Out:
# (2103, 20)

# %%
numeric = df15Camp1a._get_numeric_data()

# %%
corrmat = df15CampFinal.corr()

# %%
fig, ax = plt.subplots(figsize = (12, 9))
                       
# Generate a mask for the upper triangle (taken from seaborn example gallery)                       
mask = np.zeros_like(corrmat, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Plot the heatmap with seaborn.
# Assign the matplotlib axis the function returns. This will let us resize the labels.
ax = sns.heatmap(corrmat, mask=mask, ax=ax)

# Resize the labels.
ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=14)
ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=14)

# If you put plt.show() at the bottom, it prevents those useless printouts from matplotlib.
plt.show()

# %%
numeric = df15CampFinal._get_numeric_data()

# %%
sns.pairplot(numeric) # just a quick check for any weird patterns

# %%
sns.distplot(df15CampFinal.MedianOrderMo, bins=12, hist=True)

# %%
df15CampFinal.groupby('MedianOrderMo')['TotalPaid'].sum().sort_values(ascending=False).head(10).plot(kind='barh')

# %%
df15CampFinal.columns
# Out:
# Index(['Park', 'MedianOrderMo', 'MedianStartMo', 'Tax', 'UseFee', 'TranFee',
#        'AttrFee', 'TotalBeforeTax', 'TotalPaid', 'NumberOfPeople', 'Tent',
#        'Popup', 'Trailer', 'RVMotorhome', 'FifthWheel', 'Van', 'PickupCamper',
#        'SmallTent', 'FacilityState', 'Region'],
#       dtype='object')

# %%
df15.columns
# Out:
# Index(['HistoricalReservationID', 'OrderNumber', 'Agency', 'OrgID',
#        'CodeHierarchy', 'RegionCode', 'RegionDescription', 'ParentLocationID',
#        'ParentLocation', 'LegacyFacilityID', 'Park', 'SiteType', 'UseType',
#        'ProductID', 'EntityType', 'EntityID', 'FacilityID', 'FacilityZIP',
#        'FacilityState', 'FacilityLongitude', 'FacilityLatitude', 'CustomerZIP',
#        'CustomerState', 'CustomerCountry', 'Tax', 'UseFee', 'TranFee',
#        'AttrFee', 'TotalBeforeTax', 'TotalPaid', 'StartDate', 'EndDate',
#        'OrderDate', 'NumberOfPeople', 'Tent', 'Popup', 'Trailer',
#        'RVMotorhome', 'Boat', 'HorseTrailer', 'Car', 'FifthWheel', 'Van',
#        'CanoeKayak', 'BoatTrailer', 'Motorcycle', 'Truck', 'Bus', 'Bicycle',
#        'Snowmobile', 'OffRoadlAllTerrainVehicle', 'PowerBoat', 'PickupCamper',
#        'LargeTentOver9x12', 'SmallTent', 'Marinaboat'],
#       dtype='object')

# %%
# for_indexing =df15CampFinal[['MeanOrderMo','FacilityState','TotalPaid']]
# for_indexing

# %%
df15.head(2)
# Out:
#    HistoricalReservationID OrderNumber Agency  OrgID  \
# 0               2019039433  2-32196786   USFS    131
# 1               2019134646  2-32195127  USACE    130
#
#                        CodeHierarchy RegionCode RegionDescription  \
# 0  |1|70903|74312|74395|74751|74197|     F40204        CASCADE RD
# 1  |1|70902|74307|74362|74636|73388|  CM5002570       CANTON LAKE
#
#    ParentLocationID  ParentLocation  LegacyFacilityID     ...     Truck Bus  \
# 0             74395   BOISE NF - FS             74197     ...       NaN NaN
# 1             74362  TULSA DISTRICT             73388     ...       NaN NaN
#
#   Bicycle  Snowmobile OffRoadlAllTerrainVehicle  PowerBoat  PickupCamper  \
# 0     NaN         NaN                       NaN        NaN           NaN
# 1     NaN         NaN                       NaN        NaN           NaN
#
#   LargeTentOver9x12 SmallTent  Marinaboat
# 0               NaN       NaN         NaN
# 1               NaN       NaN         NaN
#
# [2 rows x 56 columns]

# %%
df15.groupby(['OrderDate','FacilityState'])['TotalPaid'].sum().sort_values(ascending=False).head(10).plot(kind='barh')

# %%
fig_size = plt.rcParams['figure.figsize']
var = df15[['TotalPaid','FacilityState']].groupby('FacilityState').TotalPaid.sum()
fig = plt.figure()
fig_size[0] = 15
fig_size[1] = 12
ax1 = fig.add_subplot(1,1,1,)
ax1.set_xlabel('Facility State')
ax1.set_ylabel('Total Sales')
ax1.set_title('Total Campground Sales by Facility State')
var.plot(kind = 'bar')

# %%
df15.groupby('CustomerCountry')['TotalPaid'].mean().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df15.groupby('RegionDescription')['TotalPaid'].mean().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df15.groupby('FacilityZIP')['TotalPaid'].mean().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df15CampFinal['NumberOfPeople'].mode()
# Out:
# 0    580
# dtype: int64

# %%
df15.groupby('CustomerCountry')['TotalPaid'].median().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df15.groupby('CustomerZIP')['TotalPaid'].mean().sort_values(ascending=False).head(20).plot(kind='bar')

# %%
df15.groupby('FacilityZIP')['TotalPaid'].mean().sort_values(ascending=False).head(20).plot(kind='bar')

# %% [markdown]
# As stated in the API documentaion, Zip code 92121 (San Diego, CA) has been used as a default for reservations tied to point of sales where customers' Recreation.gov profile information is not needed for the transaction (e.g., purchasing a bundle of firewood at a campground), and whether or not the customer is, or is not, from that zip code.

# %%
df15.groupby('CustomerZIP')['TotalPaid'].sum().sort_values(ascending=False).head(20).plot(kind='bar')

# %%
df15['CustomerCountry'].value_counts().head(10)
# Out:
# USA    2852155
# CAN      25962
# DEU      17216
# GBR       8200
# NLD       7702
# FRA       6595
# AUS       5481
# CHE       4643
# BEL       2213
# DNK       1633
# Name: CustomerCountry, dtype: int64

# %% [markdown]
# # Model the data

# %% [markdown]
# Next is the modeling stage. I performed several classification models. The Confusion Matrix showed that most of the items went into the Mountain category. I would like to see what happens if I do a subset of the data and run it through different models. I plan to do another model with GradientBoost.

# %%
df15CampFinal.columns
# Out:
# Index(['Park', 'MedianOrderMo', 'MedianStartMo', 'Tax', 'UseFee', 'TranFee',
#        'AttrFee', 'TotalBeforeTax', 'TotalPaid', 'NumberOfPeople', 'Tent',
#        'Popup', 'Trailer', 'RVMotorhome', 'FifthWheel', 'Van', 'PickupCamper',
#        'SmallTent', 'FacilityState', 'Region'],
#       dtype='object')

# %% [markdown]
# # Determine the Frequency of the Most Frequent Class

# %%
df15CampFinal['Region'].value_counts()
# Out:
# Pacific Coast    645
# Mountain         536
# Southwest        215
# Southeast        196
# Heartland        177
# Appalachian      173
# Midwest           98
# Mid Atlantic      26
# New England       21
# Noncontiguous     16
# Name: Region, dtype: int64

# %%
df15CampFinal['Region'].value_counts() / len(df15CampFinal['Region'])
# Out:
# Pacific Coast    0.306705
# Mountain         0.254874
# Southwest        0.102235
# Southeast        0.093200
# Heartland        0.084165
# Appalachian      0.082263
# Midwest          0.046600
# Mid Atlantic     0.012363
# New England      0.009986
# Noncontiguous    0.007608
# Name: Region, dtype: float64

# %% [markdown]
# The Baseline for the models is 30.67%

# %% [markdown]
# # Define Features and Target

# %% [markdown]
# The target variable is Region which had been created and mapped to State as mentioned above. The fact that region is is mapped to State is why State is excluded from the feature set.

# %%
X = df15CampFinal[[c for c in df15CampFinal.columns if not 'Park' in c and not 'Region' in c and not 'State' in c]]

# %%
y = df15CampFinal['Region']

# %% [markdown]
# # Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.33)

# %%
X_train.shape, y_train.shape
# Out:
# ((1409, 17), (1409,))

# %%
X_test.shape, y_test.shape
# Out:
# ((694, 17), (694,))

# %%
X.columns
# Out:
# Index(['MedianOrderMo', 'MedianStartMo', 'Tax', 'UseFee', 'TranFee', 'AttrFee',
#        'TotalBeforeTax', 'TotalPaid', 'NumberOfPeople', 'Tent', 'Popup',
#        'Trailer', 'RVMotorhome', 'FifthWheel', 'Van', 'PickupCamper',
#        'SmallTent'],
#       dtype='object')

# %%
df15CampFinal.columns
# Out:
# Index(['Park', 'MedianOrderMo', 'MedianStartMo', 'Tax', 'UseFee', 'TranFee',
#        'AttrFee', 'TotalBeforeTax', 'TotalPaid', 'NumberOfPeople', 'Tent',
#        'Popup', 'Trailer', 'RVMotorhome', 'FifthWheel', 'Van', 'PickupCamper',
#        'SmallTent', 'FacilityState', 'Region'],
#       dtype='object')

# %% [markdown]
# # Logistic Regression Model

# %% [markdown]
# The first model to be run is a logigistic regression model which is a good model to start looking at categorical data with.

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
lr.score(X_train, y_train)
# Out:
# 0.52803406671398156

# %%
lr.score(X_test, y_test)
# Out:
# 0.50432276657060515

# %%
lr_predictions = lr.predict(X_test)

# %%
X.columns
# Out:
# Index(['MedianOrderMo', 'MedianStartMo', 'Tax', 'UseFee', 'TranFee', 'AttrFee',
#        'TotalBeforeTax', 'TotalPaid', 'NumberOfPeople', 'Tent', 'Popup',
#        'Trailer', 'RVMotorhome', 'FifthWheel', 'Van', 'PickupCamper',
#        'SmallTent'],
#       dtype='object')

# %%
lr.coef_
# Out:
# array([[ -7.56157680e-02,  -2.55774688e-01,  -4.78571372e-02,
#           1.54469659e-04,   3.91231051e-05,   2.27546375e-04,
#           3.09920011e-03,  -3.25371255e-03,  -6.37137516e-05,
#           3.76117753e-04,   1.39092230e-02,   1.53497465e-03,
#          -1.47142685e-03,  -1.51357465e-03,   6.26904556e-03,
#          -1.92187934e-02,  -3.98388848e-03],
#        [ -1.21952230e-01,  -2.09131069e-01,  -2.20262864e-02,
#           6.20717048e-04,   2.41888510e-04,   5.63841576e-04,
#           2.39054029e-02,  -2.45255215e-02,  -2.67044630e-04,
#          -2.82293719e-04,   4.75893968e-02,  -6.88240065e-03,
#          -1.38192829e-02,   2.21672975e-02,  -4.30469985e-02,
#           2.74423669e-02,   6.58275478e-04],
#        [ -1.25040440e-01,  -1.74614059e-01,  -1.64083308e-02,
#          -8.51608055e-04,  -1.58462220e-03,  -8.04997148e-04,
#           1.71090470e-02,  -1.61573898e-02,  -1.07800895e-03,
#           2.01549325e-03,  -8.98643120e-03,   7.20305149e-03,
#          -2.49663286e-03,  -2.38360328e-02,  -3.51788717e-02,
#          -3.66568737e-02,   9.61428741e-03],
#        [ -1.49572921e-01,  -2.60187200e-01,  -5.57887105e-02,
#           3.32596542e-03,   3.23697344e-03,   3.34454895e-03,
#          -3.86223718e-02,   3.52722015e-02,   6.13823519e-05,
#           1.66544007e-03,   8.67742864e-03,   1.01809236e-02,
#          -7.76198371e-04,  -6.22608715e-03,  -8.79691122e-02,
#           6.37228649e-03,  -7.73222021e-03],
#        [ -8.99655339e-02,  -5.05898358e-02,  -4.82300416e-03,
#          -3.92933069e-04,  -1.87198594e-04,  -3.96237191e-04,
#          -4.22003338e-03,   4.51173837e-03,   1.91327492e-04,
#          -8.17167508e-04,   2.86319628e-02,   3.35545697e-03,
#           5.20221356e-03,  -1.53493001e-02,   1.83886970e-02,
#           9.56078503e-03,  -9.72462242e-03],
#        [ -2.19508192e-01,  -3.71302887e-01,  -3.09218494e-02,
#           2.18150261e-03,   1.97906900e-03,  -7.29938657e-03,
#           1.50411711e-02,  -1.71122757e-02,  -4.75989387e-04,
#          -5.61542599e-04,   4.77045167e-02,   4.33983301e-03,
#          -6.86249661e-03,  -9.77532880e-02,  -4.26709739e-02,
#          -1.22288576e-01,  -7.04495994e-02],
#        [ -1.64792768e-01,  -3.19318296e-01,  -1.87494408e-01,
#           1.66190065e-02,   2.98341014e-02,  -5.61003723e-03,
#           8.47851394e-02,  -1.02865365e-01,  -5.41887351e-03,
#          -1.19133616e-01,   8.03698338e-03,  -1.40110277e-01,
#           1.05543954e-01,  -3.01233142e-01,   2.58935895e-01,
#           2.73469559e-01,  -2.89265042e-01],
#        [ -4.52126750e-02,  -5.38188898e-02,   4.66316580e-03,
#          -1.01903165e-03,  -9.04274413e-04,  -1.01915264e-03,
#           2.66600510e-03,  -1.58744120e-03,  -2.09481094e-04,
#           3.57503932e-04,  -7.73785857e-02,   1.89787143e-03,
#          -4.88577645e-03,  -2.91596510e-02,   7.80135914e-04,
#           5.86713669e-02,  -1.36799304e-03],
#        [ -2.96946950e-02,  -3.02247946e-01,  -3.93156802e-02,
#           3.93732390e-05,  -1.44615075e-04,   7.79967575e-05,
#           1.53100072e-02,  -1.53233832e-02,  -8.12226365e-05,
#          -1.06437412e-03,  -4.65186610e-03,   1.49897307e-03,
#           8.95236454e-04,  -2.50502287e-03,   3.66965139e-03,
#          -1.20762098e-02,  -5.83523873e-04],
#        [ -8.76316103e-02,  -2.47005953e-01,  -2.83129590e-02,
#          -1.99217395e-04,  -2.10003195e-05,  -1.59610205e-04,
#          -2.56146201e-02,   2.57512801e-02,   1.72957992e-04,
#          -2.75724791e-04,   1.90038768e-04,  -6.83815537e-04,
#           5.85623735e-03,   8.69325672e-03,   1.48745977e-03,
#          -4.19170709e-02,   5.37120124e-03]])

# %%
index=X.columns
index
# Out:
# Index(['MedianOrderMo', 'MedianStartMo', 'Tax', 'UseFee', 'TranFee', 'AttrFee',
#        'TotalBeforeTax', 'TotalPaid', 'NumberOfPeople', 'Tent', 'Popup',
#        'Trailer', 'RVMotorhome', 'FifthWheel', 'Van', 'PickupCamper',
#        'SmallTent'],
#       dtype='object')

# %%
lr.coef_.shape
# Out:
# (10, 17)

# %%
cols = ['MeanOrderMo', 'MeanStartMo', 'Tax', 'UseFee', 'TranFee', 'AttrFee','TotalBeforeTax', 'TotalPaid', 'NumberOfPeople', 'Tent', 'Popup','Trailer', 'RVMotorhome', 'FifthWheel', 'Van', 'PickupCamper', 'SmallTent']

# %%
coeff_df = pd.DataFrame(lr.coef_,index=lr.classes_, columns=cols )

# %%
df15CampFinal.groupby('Region')['MedianOrderMo'].mean()
# Out:
# Region
# Appalachian      5.494220
# Heartland        5.412429
# Mid Atlantic     5.423077
# Midwest          5.505102
# Mountain         4.948694
# New England      6.095238
# Noncontiguous    5.312500
# Pacific Coast    4.948837
# Southeast        4.974490
# Southwest        4.709302
# Name: MedianOrderMo, dtype: float64

# %%
df15CampFinal.groupby('Region')['MedianStartMo'].mean()
# Out:
# Region
# Appalachian      7.031792
# Heartland        6.954802
# Mid Atlantic     7.153846
# Midwest          7.091837
# Mountain         7.085821
# New England      7.333333
# Noncontiguous    7.000000
# Pacific Coast    7.044961
# Southeast        6.346939
# Southwest        6.332558
# Name: MedianStartMo, dtype: float64

# %%
coeff_df
# Out:
#                MeanOrderMo  MeanStartMo       Tax    UseFee   TranFee  \
# Appalachian      -0.075616    -0.255775 -0.047857  0.000154  0.000039
# Heartland        -0.121952    -0.209131 -0.022026  0.000621  0.000242
# Mid Atlantic     -0.125040    -0.174614 -0.016408 -0.000852 -0.001585
# Midwest          -0.149573    -0.260187 -0.055789  0.003326  0.003237
# Mountain         -0.089966    -0.050590 -0.004823 -0.000393 -0.000187
# New England      -0.219508    -0.371303 -0.030922  0.002182  0.001979
# Noncontiguous    -0.164793    -0.319318 -0.187494  0.016619  0.029834
# Pacific Coast    -0.045213    -0.053819  0.004663 -0.001019 -0.000904
# Southeast        -0.029695    -0.302248 -0.039316  0.000039 -0.000145
# Southwest        -0.087632    -0.247006 -0.028313 -0.000199 -0.000021
#
#                 AttrFee  TotalBeforeTax  TotalPaid  NumberOfPeople      Tent  \
# Appalachian    0.000228        0.003099  -0.003254       -0.000064  0.000376
# Heartland      0.000564        0.023905  -0.024526       -0.000267 -0.000282
# Mid Atlantic  -0.000805        0.017109  -0.016157       -0.001078  0.002015
# Midwest        0.003345       -0.038622   0.035272        0.000061  0.001665
# Mountain      -0.000396       -0.004220   0.004512        0.000191 -0.000817
# New England   -0.007299        0.015041  -0.017112       -0.000476 -0.000562
# Noncontiguous -0.005610        0.084785  -0.102865       -0.005419 -0.119134
# Pacific Coast -0.001019        0.002666  -0.001587       -0.000209  0.000358
# Southeast      0.000078        0.015310  -0.015323       -0.000081 -0.001064
# Southwest     -0.000160       -0.025615   0.025751        0.000173 -0.000276
#
#                   Popup   Trailer  RVMotorhome  FifthWheel       Van  \
# Appalachian    0.013909  0.001535    -0.001471   -0.001514  0.006269
# Heartland      0.047589 -0.006882    -0.013819    0.022167 -0.043047
# Mid Atlantic  -0.008986  0.007203    -0.002497   -0.023836 -0.035179
# Midwest        0.008677  0.010181    -0.000776   -0.006226 -0.087969
# Mountain       0.028632  0.003355     0.005202   -0.015349  0.018389
# New England    0.047705  0.004340    -0.006862   -0.097753 -0.042671
# Noncontiguous  0.008037 -0.140110     0.105544   -0.301233  0.258936
# Pacific Coast -0.077379  0.001898    -0.004886   -0.029160  0.000780
# Southeast     -0.004652  0.001499     0.000895   -0.002505  0.003670
# Southwest      0.000190 -0.000684     0.005856    0.008693  0.001487
#
#                PickupCamper  SmallTent
# Appalachian       -0.019219  -0.003984
# Heartland          0.027442   0.000658
# Mid Atlantic      -0.036657   0.009614
# Midwest            0.006372  -0.007732
# Mountain           0.009561  -0.009725
# New England       -0.122289  -0.070450
# Noncontiguous      0.273470  -0.289265
# Pacific Coast      0.058671  -0.001368
# Southeast         -0.012076  -0.000584
# Southwest         -0.041917   0.005371

# %%
print(classification_report(y_test,lr_predictions))
# Out:
#                precision    recall  f1-score   support
#
#   Appalachian       0.40      0.08      0.13        50
#     Heartland       0.70      0.48      0.57        58
#  Mid Atlantic       0.25      0.12      0.17         8
#       Midwest       0.17      0.03      0.05        31
#      Mountain       0.51      0.51      0.51       188
#   New England       0.00      0.00      0.00         8
# Noncontiguous       0.33      0.57      0.42         7
# Pacific Coast       0.51      0.92      0.66       211
#     Southeast       0.41      0.14      0.20        66
#     Southwest       0.41      0.21      0.28        67
#
#   avg / total       0.47      0.50      0.45       694

# %% [markdown]
# # GridSearchCV

# %% [markdown]
# Next, run the logistic regression with a GridSearchCV. This will allow for multiple parameters to achieve the best score.

# %%
params = {'C':  [5, 6, 7, 8, 10]}

# %%
grid_lr = GridSearchCV(LogisticRegression(), param_grid=params, cv=5, n_jobs=-1)

# %%
grid_lr.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'C': [5, 6, 7, 8, 10]}, pre_dispatch='2*n_jobs',
#        refit=True, return_train_score=True, scoring=None, verbose=0)

# %%
grid_lr.score(X_train, y_train)
# Out:
# 0.5266146202980837

# %%
grid_lr.score(X_test, y_test)
# Out:
# 0.50720461095100866

# %%
grid_lr.best_score_
# Out:
# 0.50816181689141238

# %%
grid_lr.best_params_
# Out:
# {'C': 5}

# %%
grid_lr_predictions = grid_lr.predict(X_test)

# %%
scores = cross_val_score(lr, X, y, cv=5)
print('Cross-validated scores =', scores)
# Out:
# Cross-validated scores = [ 0.51173709  0.47980998  0.54047619  0.51674641  0.49282297]

# %% [markdown]
# # Confusion Matrix

# %%
grid_lr_preds = grid_lr.predict(X_test)

def conmatrix(predictions, y, model):
    conmat_1 = confusion_matrix(y, predictions, labels=model.classes_)
    conmat_1 = pd.DataFrame(conmat_1, columns=model.classes_, index=model.classes_)
    return conmat_1
    

conmatrix(predictions=grid_lr_preds,y=y_test,model=lr)
# Out:
#                Appalachian  Heartland  Mid Atlantic  Midwest  Mountain  \
# Appalachian              4          2             0        0        26
# Heartland                2         26             0        1        18
# Mid Atlantic             0          0             0        0         4
# Midwest                  2          1             0        1        18
# Mountain                 0          2             0        3       116
# New England              0          0             2        0         3
# Noncontiguous            0          0             0        0         1
# Pacific Coast            0          0             0        0        30
# Southeast                2          4             1        2        32
# Southwest                0          3             0        3        18
#
#                New England  Noncontiguous  Pacific Coast  Southeast  Southwest
# Appalachian              1              0             10          4          3
# Heartland                0              0              9          0          2
# Mid Atlantic             0              0              3          1          0
# Midwest                  1              1              3          0          4
# Mountain                 0              3             61          0          3
# New England              0              0              3          0          0
# Noncontiguous            0              4              2          0          0
# Pacific Coast            0              0            179          1          1
# Southeast                0              4              6         10          5
# Southwest                0              0             22          9         12

# %%
print(classification_report(y_test,grid_lr_preds))
# Out:
#                precision    recall  f1-score   support
#
#   Appalachian       0.40      0.08      0.13        50
#     Heartland       0.68      0.45      0.54        58
#  Mid Atlantic       0.00      0.00      0.00         8
#       Midwest       0.10      0.03      0.05        31
#      Mountain       0.44      0.62      0.51       188
#   New England       0.00      0.00      0.00         8
# Noncontiguous       0.33      0.57      0.42         7
# Pacific Coast       0.60      0.85      0.70       211
#     Southeast       0.40      0.15      0.22        66
#     Southwest       0.40      0.18      0.25        67
#
#   avg / total       0.47      0.51      0.46       694

# %% [markdown]
# # Decision Tree Classifier

# %% [markdown]
# Below is a Decision Tree Classifier. Also , there isa graph of the decision tree and another Confusion matrix related to this model.

# %%
dt = DecisionTreeClassifier(max_depth=3)

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
dt.score(X_test, y_test)
# Out:
# 0.41930835734870314

# %%
dt.feature_importances_
# Out:
# array([ 0.        ,  0.14102945,  0.16045411,  0.04435185,  0.12342861,
#         0.        ,  0.        ,  0.        ,  0.        ,  0.13784226,
#         0.03574378,  0.        ,  0.        ,  0.35714994,  0.        ,
#         0.        ,  0.        ])

# %%
dt.predict(X_test)
# Out:
# array(['Heartland', 'Mountain', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Heartland',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Heartland', 'Pacific Coast', 'Southwest', 'Mountain', 'Mountain',
#        'Mountain', 'Heartland', 'Southeast', 'Pacific Coast', 'Mountain',
#        'Southwest', 'Mountain', 'Mountain', 'Mountain', 'Heartland',
#        'Pacific Coast', 'Mountain', 'Pacific Coast', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Heartland', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Southwest', 'Mountain', 'Mountain', 'Heartland',
#        'Mountain', 'Mountain', 'Southeast', 'Mountain', 'Mountain',
#        'Mountain', 'Heartland', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Heartland', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Pacific Coast', 'Pacific Coast',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Heartland', 'Pacific Coast', 'Mountain', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Southeast', 'Mountain', 'Mountain', 'Mountain', 'Heartland',
#        'Mountain', 'Mountain', 'Heartland', 'Mountain', 'Mountain',
#        'Mountain', 'Heartland', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Pacific Coast', 'Mountain', 'Pacific Coast',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Pacific Coast',
#        'Mountain', 'Southeast', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Heartland', 'Mountain', 'Mountain',
#        'Heartland', 'Mountain', 'Mountain', 'Southeast', 'Pacific Coast',
#        'Southeast', 'Mountain', 'Southeast', 'Mountain', 'Heartland',
#        'Mountain', 'Pacific Coast', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Pacific Coast', 'Mountain', 'Southwest', 'Southeast',
#        'Mountain', 'Southeast', 'Mountain', 'Southeast', 'Heartland',
#        'Mountain', 'Mountain', 'Mountain', 'Pacific Coast', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Pacific Coast', 'Mountain', 'Pacific Coast',
#        'Southwest', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Heartland', 'Heartland', 'Pacific Coast', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Pacific Coast', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Pacific Coast', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Heartland', 'Pacific Coast',
#        'Pacific Coast', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Heartland', 'Mountain', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Southeast', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Heartland', 'Pacific Coast', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Southeast', 'Mountain',
#        'Mountain', 'Pacific Coast', 'Mountain', 'Mountain', 'Mountain',
#        'Southeast', 'Pacific Coast', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Southeast',
#        'Mountain', 'Mountain', 'Mountain', 'Heartland', 'Heartland',
#        'Pacific Coast', 'Mountain', 'Mountain', 'Pacific Coast',
#        'Heartland', 'Southeast', 'Mountain', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Mountain', 'Mountain', 'Southeast',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Pacific Coast', 'Mountain', 'Mountain', 'Heartland',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Pacific Coast', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Heartland', 'Southeast', 'Heartland',
#        'Mountain', 'Heartland', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Southeast', 'Mountain', 'Mountain', 'Southeast', 'Mountain',
#        'Pacific Coast', 'Heartland', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Pacific Coast',
#        'Southeast', 'Mountain', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Pacific Coast',
#        'Mountain', 'Pacific Coast', 'Pacific Coast', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Heartland', 'Mountain',
#        'Mountain', 'Mountain', 'Heartland', 'Pacific Coast', 'Mountain',
#        'Mountain', 'Heartland', 'Mountain', 'Southwest', 'Pacific Coast',
#        'Mountain', 'Pacific Coast', 'Mountain', 'Mountain', 'Southeast',
#        'Pacific Coast', 'Mountain', 'Mountain', 'Mountain', 'Southeast',
#        'Mountain', 'Mountain', 'Pacific Coast', 'Mountain', 'Heartland',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Pacific Coast',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Heartland', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Heartland',
#        'Southeast', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Mountain', 'Pacific Coast', 'Mountain', 'Mountain', 'Mountain',
#        'Heartland', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Heartland', 'Mountain', 'Southeast', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Mountain', 'Heartland', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Heartland', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Heartland', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Pacific Coast', 'Pacific Coast', 'Pacific Coast',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Heartland', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Heartland', 'Pacific Coast', 'Mountain', 'Mountain', 'Mountain',
#        'Heartland', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Pacific Coast', 'Pacific Coast',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Pacific Coast', 'Mountain',
#        'Mountain', 'Pacific Coast', 'Mountain', 'Mountain', 'Southeast',
#        'Mountain', 'Pacific Coast', 'Mountain', 'Mountain', 'Mountain',
#        'Southeast', 'Mountain', 'Mountain', 'Mountain', 'Pacific Coast',
#        'Mountain', 'Mountain', 'Pacific Coast', 'Pacific Coast',
#        'Pacific Coast', 'Heartland', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Mountain', 'Southeast', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Pacific Coast',
#        'Pacific Coast', 'Pacific Coast', 'Mountain', 'Pacific Coast',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Southeast',
#        'Mountain', 'Heartland', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Pacific Coast', 'Southwest', 'Southeast', 'Mountain',
#        'Mountain', 'Heartland', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Pacific Coast',
#        'Mountain', 'Mountain', 'Pacific Coast', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Pacific Coast', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Pacific Coast', 'Pacific Coast',
#        'Mountain', 'Pacific Coast', 'Pacific Coast', 'Heartland',
#        'Heartland', 'Mountain', 'Mountain', 'Pacific Coast',
#        'Pacific Coast', 'Pacific Coast', 'Mountain', 'Pacific Coast',
#        'Heartland', 'Mountain', 'Mountain', 'Mountain', 'Pacific Coast',
#        'Pacific Coast', 'Mountain', 'Mountain', 'Southeast', 'Mountain',
#        'Southeast', 'Pacific Coast', 'Mountain', 'Southeast', 'Mountain',
#        'Mountain', 'Mountain', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Pacific Coast', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Southeast', 'Southeast', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Southwest', 'Mountain',
#        'Heartland', 'Mountain', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Heartland', 'Mountain', 'Pacific Coast', 'Mountain', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain',
#        'Mountain', 'Heartland', 'Mountain', 'Southeast', 'Mountain',
#        'Mountain', 'Mountain', 'Mountain', 'Heartland', 'Mountain',
#        'Heartland', 'Mountain', 'Mountain', 'Mountain', 'Pacific Coast',
#        'Mountain', 'Mountain', 'Mountain', 'Pacific Coast', 'Mountain',
#        'Southwest'], dtype=object)

# %%
dt_feat_imp = dt.feature_importances_

# %%
dt_feat_imp_df = pd.DataFrame(X.columns, dt_feat_imp )

# %%
dt_feat_imp_df
# Out:
#                        0
# 0.000000   MedianOrderMo
# 0.141029   MedianStartMo
# 0.160454             Tax
# 0.044352          UseFee
# 0.123429         TranFee
# 0.000000         AttrFee
# 0.000000  TotalBeforeTax
# 0.000000       TotalPaid
# 0.000000  NumberOfPeople
# 0.137842            Tent
# 0.035744           Popup
# 0.000000         Trailer
# 0.000000     RVMotorhome
# 0.357150      FifthWheel
# 0.000000             Van
# 0.000000    PickupCamper
# 0.000000       SmallTent

# %%
dt_feat_imp_df.rename(columns={'index':'Feature Importance'}, inplace=True)

# %%
dt_feat_imp_df.columns = ['Features'] # Rename column 'Features

# %%
dt_feat_imp_df = dt_feat_imp_df.reset_index().sort_values(by='index', ascending=False)

# %%
dt_feat_imp_df
# Out:
#        index        Features
# 13  0.357150      FifthWheel
# 2   0.160454             Tax
# 1   0.141029   MedianStartMo
# 9   0.137842            Tent
# 4   0.123429         TranFee
# 3   0.044352          UseFee
# 10  0.035744           Popup
# 0   0.000000   MedianOrderMo
# 12  0.000000     RVMotorhome
# 15  0.000000    PickupCamper
# 14  0.000000             Van
# 8   0.000000  NumberOfPeople
# 11  0.000000         Trailer
# 7   0.000000       TotalPaid
# 6   0.000000  TotalBeforeTax
# 5   0.000000         AttrFee
# 16  0.000000       SmallTent

# %% [markdown]
# # Graph the Decision Tree

# %%
# REQUIREMENTS:
# pip install pydot2
# brew install graphviz

# Use graphviz to make a chart of the regression tree decision points:
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

dot_data = StringIO()  

export_graphviz(dt, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,
               feature_names=df15CampFinal.columns, 
               class_names=dt.classes_)  

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# # Confusion Matrix

# %%
# predict test class:
dt_pred = dt.predict(X_test)

# predicted test probability:
y_pp = dt.predict_proba(X_test)

# %%
def conmatrix(ypreds, ytrue, model):
    conmat_1 = confusion_matrix(ytrue, ypreds, labels=model.classes_)
    conmat_1 = pd.DataFrame(conmat_1, columns=model.classes_, index=model.classes_)
    return conmat_1
    
conmatrix(ypreds=dt_pred,ytrue=y_test,model=dt)

print(classification_report(y_test,dt_pred))
# Out:
#                precision    recall  f1-score   support
#
#   Appalachian       0.00      0.00      0.00        50
#     Heartland       0.47      0.45      0.46        58
#  Mid Atlantic       0.00      0.00      0.00         8
#       Midwest       0.00      0.00      0.00        31
#      Mountain       0.35      0.90      0.51       188
#   New England       0.00      0.00      0.00         8
# Noncontiguous       0.00      0.00      0.00         7
# Pacific Coast       0.69      0.37      0.49       211
#     Southeast       0.29      0.15      0.20        66
#     Southwest       0.67      0.09      0.16        67
#
#   avg / total       0.44      0.42      0.36       694
# /anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# # Random Forest Classifier

# %% [markdown]
# Next model is a Random Forest Classifier. Below is a Confusion Matrix and a Classification Report to give an idea how the model did in predicting the regions.

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
rf.score(X_test, y_test)
# Out:
# 0.50720461095100866

# %%
rf_predictions = rf.predict(X_test)

# %% [markdown]
# # Confusion Matrix

# %%
def conmatrix(predictions, y, model):
    conmat_1 = confusion_matrix(y, predictions, labels=model.classes_)
    conmat_1 = pd.DataFrame(conmat_1, columns=model.classes_, index=model.classes_)
    return conmat_1
    

conmatrix(predictions=rf_predictions,y=y_test,model=rf)
# Out:
#                Appalachian  Heartland  Mid Atlantic  Midwest  Mountain  \
# Appalachian             15          2             1        6        10
# Heartland                7         23             0        3         4
# Mid Atlantic             1          1             0        0         3
# Midwest                  3          4             0        4        11
# Mountain                 6          4             1        1       112
# New England              1          0             0        0         1
# Noncontiguous            0          0             0        0         2
# Pacific Coast            1          3             6        3        35
# Southeast               11          8             0        2        14
# Southwest                2          0             0        1         9
#
#                New England  Noncontiguous  Pacific Coast  Southeast  Southwest
# Appalachian              0              0             12          4          0
# Heartland                0              0              8          6          7
# Mid Atlantic             0              0              2          0          1
# Midwest                  0              0              7          2          0
# Mountain                 1              0             59          1          3
# New England              0              0              5          1          0
# Noncontiguous            0              0              5          0          0
# Pacific Coast            0              0            157          1          5
# Southeast                0              0              6         20          5
# Southwest                0              0             15         19         21

# %%
rf.feature_importances_
# Out:
# array([ 0.04045138,  0.04466159,  0.01912079,  0.07136505,  0.10157736,
#         0.01371141,  0.06215038,  0.0704421 ,  0.08915324,  0.08653236,
#         0.07125059,  0.06792078,  0.0599763 ,  0.10182894,  0.04454518,
#         0.04602623,  0.00928633])

# %%
print(classification_report(y_test,rf_predictions))
# Out:
#                precision    recall  f1-score   support
#
#   Appalachian       0.32      0.30      0.31        50
#     Heartland       0.51      0.40      0.45        58
#  Mid Atlantic       0.00      0.00      0.00         8
#       Midwest       0.20      0.13      0.16        31
#      Mountain       0.56      0.60      0.58       188
#   New England       0.00      0.00      0.00         8
# Noncontiguous       0.00      0.00      0.00         7
# Pacific Coast       0.57      0.74      0.64       211
#     Southeast       0.37      0.30      0.33        66
#     Southwest       0.50      0.31      0.39        67
#
#   avg / total       0.48      0.51      0.49       694
# /anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
feature_imp = pd.DataFrame(rf.feature_importances_, index=X.columns)

# %%
feature_imp.sort_values(by=[0], ascending=False) # Feature Importances
# Out:
#                        0
# FifthWheel      0.101829
# TranFee         0.101577
# NumberOfPeople  0.089153
# Tent            0.086532
# UseFee          0.071365
# Popup           0.071251
# TotalPaid       0.070442
# Trailer         0.067921
# TotalBeforeTax  0.062150
# RVMotorhome     0.059976
# PickupCamper    0.046026
# MedianStartMo   0.044662
# Van             0.044545
# MedianOrderMo   0.040451
# Tax             0.019121
# AttrFee         0.013711
# SmallTent       0.009286

# %% [markdown]
# # Gradient Boost

# %%
gb = GradientBoostingClassifier()

# %%
gb.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_split=1e-07, min_samples_leaf=1,
#               min_samples_split=2, min_weight_fraction_leaf=0.0,
#               n_estimators=100, presort='auto', random_state=None,
#               subsample=1.0, verbose=0, warm_start=False)

# %%
gb.score(X_test, y_test)
# Out:
# 0.5331412103746398

# %%
gb_predictions = gb.predict(X_test)

# %%
scores = cross_val_score(gb, X, y, cv=5)
print('Cross-validated scores =', scores)
# Out:
# Cross-validated scores = [ 0.54460094  0.55581948  0.55952381  0.53110048  0.55980861]

# %%
feature_imp = pd.DataFrame(gb.feature_importances_, index=X.columns)
feature_imp.sort_values(by=[0], ascending=False)
# Out:
#                        0
# TranFee         0.132493
# NumberOfPeople  0.119138
# UseFee          0.091823
# Popup           0.087096
# Tent            0.074899
# FifthWheel      0.070944
# RVMotorhome     0.065017
# Trailer         0.064942
# PickupCamper    0.048377
# TotalBeforeTax  0.046578
# TotalPaid       0.045237
# MedianOrderMo   0.035785
# AttrFee         0.033969
# MedianStartMo   0.029612
# Van             0.029521
# SmallTent       0.019894
# Tax             0.004675

# %% [markdown]
# # Confusion Matrix

# %%
gb_preds = gb.predict(X_test)

def conmatrix(predictions, y, model):
    conmat_1 = confusion_matrix(y, predictions, labels=model.classes_)
    conmat_1 = pd.DataFrame(conmat_1, columns=model.classes_, index=model.classes_)
    return conmat_1
    

cm = conmatrix(predictions=gb_preds,y=y_test,model=gb)
cm
# Out:
#                Appalachian  Heartland  Mid Atlantic  Midwest  Mountain  \
# Appalachian             12          6             2        3         8
# Heartland                4         27             0        3         7
# Mid Atlantic             1          0             0        1         2
# Midwest                  2          5             0        3        10
# Mountain                 4          3             0        1       117
# New England              1          0             0        1         1
# Noncontiguous            2          0             0        0         2
# Pacific Coast            1          1             0        2        43
# Southeast                7         12             0        0         6
# Southwest                1          2             0        1         8
#
#                New England  Noncontiguous  Pacific Coast  Southeast  Southwest
# Appalachian              0              0             12          6          1
# Heartland                0              0              5          4          8
# Mid Atlantic             0              0              2          1          1
# Midwest                  0              0              8          0          3
# Mountain                 0              0             57          2          4
# New England              0              0              4          1          0
# Noncontiguous            0              0              3          0          0
# Pacific Coast            0              0            161          0          3
# Southeast                0              0              9         22         10
# Southwest                0              0             16         11         28

# %%
fig, ax = plt.subplots(figsize = (9, 9))
                       
# Generate a mask for the upper triangle (taken from seaborn example gallery)                       
mask = np.zeros_like(cm, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Plot the heatmap with seaborn.
# Assign the matplotlib axis the function returns. This will let us resize the labels.
ax = sns.heatmap(cm, mask=mask, ax=ax)

# Resize the labels.
ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=14)
ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=14)

# If you put plt.show() at the bottom, it prevents those useless printouts from matplotlib.
plt.show()

# %%
print(classification_report(y_test,gb_preds))
# Out:
#                precision    recall  f1-score   support
#
#   Appalachian       0.34      0.24      0.28        50
#     Heartland       0.48      0.47      0.47        58
#  Mid Atlantic       0.00      0.00      0.00         8
#       Midwest       0.20      0.10      0.13        31
#      Mountain       0.57      0.62      0.60       188
#   New England       0.00      0.00      0.00         8
# Noncontiguous       0.00      0.00      0.00         7
# Pacific Coast       0.58      0.76      0.66       211
#     Southeast       0.47      0.33      0.39        66
#     Southwest       0.48      0.42      0.45        67
#
#   avg / total       0.50      0.53      0.51       694
# /anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
